# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import json
#os.chdir('c:\scan')
#print(os.getcwd())
with open('events.json') as HomeWork:
    content = HomeWork.read()
    temp = json.loads(content)
df = pd.DataFrame(temp["events"])

counts=df['signature'].value_counts()
plt.figure(figsize=(12,12))

# %%
counts.plot(kind='bar')
# Out:
# <Axes: xlabel='signature'>
